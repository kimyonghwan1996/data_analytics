# %% [markdown]
# ## CNN fashion_mnist

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# 데이터 로드 및 전처리
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
plt.show()

# %%
# 모델 생성
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# 모델 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 데이터 전처리 (이미지 shape 변경)
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)

# %%
# 모델 훈련
model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels))

# 모델 평가
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.4720 - accuracy: 0.8301 - val_loss: 0.3442 - val_accuracy: 0.8762
# Epoch 2/5
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.3111 - accuracy: 0.8867 - val_loss: 0.2965 - val_accuracy: 0.8926
# Epoch 3/5
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.2654 - accuracy: 0.9014 - val_loss: 0.2773 - val_accuracy: 0.8956
# Epoch 4/5
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2380 - accuracy: 0.9115 - val_loss: 0.2581 - val_accuracy: 0.9016
# Epoch 5/5
# ...
# 313/313 [==============================] - 2s 8ms/step - loss: 0.2479 - accuracy: 0.9080
# Test Accuracy: 0.9079999923706055

# %%
# !pip install pydot 
# !pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

# 모델 그림 그리기
plot_model(model, to_file='fashion_mnist_model.png', show_shapes=True, show_layer_names=True)

# 모델 그림 화면에 출력
img = plt.imread('fashion_mnist_model.png')
plt.imshow(img)
plt.show()
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# 데이터 로드 및 전처리
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# 모델 생성
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu')) #추가
model.add(Flatten())
model.add(Dense(256, activation='relu'))#추가
model.add(Dropout(0.5))#추가
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))



# 모델 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 데이터 전처리 (이미지 shape 변경)
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)

# %%
# 모델 훈련
model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# 모델 평가
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.5705 - accuracy: 0.7917 - val_loss: 0.3878 - val_accuracy: 0.8600
# Epoch 2/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3587 - accuracy: 0.8717 - val_loss: 0.3248 - val_accuracy: 0.8840
# Epoch 3/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3068 - accuracy: 0.8910 - val_loss: 0.2911 - val_accuracy: 0.8957
# Epoch 4/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2723 - accuracy: 0.9017 - val_loss: 0.2904 - val_accuracy: 0.8963
# Epoch 5/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2493 - accuracy: 0.9104 - val_loss: 0.2642 - val_accuracy: 0.9080
# Epoch 6/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2296 - accuracy: 0.9158 - val_loss: 0.2781 - val_accuracy: 0.9041
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

# 모델 그림 그리기
plot_model(model, to_file='fashion_mnist_model.png', show_shapes=True, show_layer_names=True)

# 모델 그림 화면에 출력
img = plt.imread('fashion_mnist_model.png')
plt.imshow(img)
plt.show()
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
