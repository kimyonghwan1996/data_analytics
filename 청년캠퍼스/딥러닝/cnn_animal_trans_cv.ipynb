# %% [markdown]
# # CNN 이미지 분류 - 전이학습

# %%
# 경고(worning) 무시
import warnings
warnings.filterwarnings('ignore')

# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

key = "6a77e04939b39922140fe0033ad87fbd"
secret = "867c278824b691dc"


def download(keyword, dir):  

    newdir = "./image/" + dir 
    
    if not os.path.exists(newdir):
        os.mkdir(newdir)    
        
    flickr = FlickrAPI(key, secret, format='parsed-json')
    res = flickr.photos.search(
      text = keyword,     
      per_page = 100,     
      media = 'photos',   
      sort = "relevance", 
      safe_search = 1,    
      extras = 'url_q, license')
    
    photos = res['photos']
   
    
    try:
        for i, photo in enumerate(photos['photo']):
            url_q = photo['url_q']
            filepath = './image/' + dir + '/' + str(i) + '.jpg'
            print(url_q)
            urlretrieve(url_q, filepath)
            time.sleep(1)
    except:
        import traceback
        traceback.print_exc()
        
def main():
#     download('dog animal', 'dog')
#     download('deer animal', 'deer')
#     download('cat animal', 'cat')
    print("download completed...")

if __name__ == '__main__':
    main()
# Out:
# download completed...

# %%
import numpy as np
from PIL import Image
import os, glob, random

outfile = "image/photos.npz" 
max_photo = 100 
photo_size = 32 
x = [] 
y = [] 

def main():    
    glob_files("./image/dog", 0)   
    glob_files("./image/deer", 1)
    glob_files("./image/cat", 2)
    
    np.savez(outfile, x=x, y=y)  
    print("Number of images : ", str(len(x)))

def glob_files(path, label): 
    files = glob.glob(path + "/*.jpg")
   
    num = 0
    for f in files:
        if num >= max_photo: break
        num += 1
        img = Image.open(f)
        img = img.convert("RGB")  
        img = img.resize((photo_size, photo_size))  
        img = np.asarray(img) 
        x.append(img)
        y.append(label)
        
if __name__ == '__main__':
    main()
# Out:
# Number of images :  300

# %% [markdown]
# #### 동물 종류별로 제대로 변환되었는지 이미지 확인하기

# %%
import matplotlib.pyplot as plt
import numpy as np

photos = np.load("image/photos.npz")
x = photos["x"]
y = photos["y"]

idx = 0  

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.title(y[i+idx])
    plt.imshow(x[i+idx])
    
plt.show()

# %% [markdown]
# ###  데이타 전처리

# %%
import tensorflow.keras
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

 
im_rows = 32  
im_cols = 32  
im_color = 3  
in_shape = (im_rows, im_cols, im_color)  
nb_classes = 3  

 
photos = np.load('image/photos.npz')
X = photos['x']
y = photos['y']
print((X.shape, y.shape))
print((X[0]))
 
X = x.reshape(-1, im_rows, im_cols, im_color)
X = x.astype('float32') / 255
print((X.shape))
print((X[0]))

 
y = to_categorical(y.astype('int32'), nb_classes) # nb_classes=3
# Out:
# ((300, 32, 32, 3), (300,))
# [[[164 199 142]
#   [173 202 158]
#   [180 210 168]
#   ...
#   [192 224 166]
#   [207 231 173]
#   [208 227 164]]
#
#  [[136 174 126]
#   [150 183 146]
#   [161 192 153]
#   ...
#   [212 231 169]
#   [196 222 157]
#   [208 230 166]]
#
#  [[136 171 130]
#   [146 178 142]
#   [156 181 139]
#   ...
#   [212 227 175]
#   [196 215 163]
#   [188 209 162]]
#
#  ...
#
#  [[ 78 111 109]
#   [ 70 100  94]
#   [ 92 125 117]
#   ...
#   [105 111 100]
#   [ 80  85  74]
#   [121 123 107]]
#
#  [[108 121 121]
#   [104 112 119]
#   [101 121 117]
#   ...
#   [129 146 130]
#   [104 138 117]
#   [124 147 129]]
#
#  [[119 137 128]
#   [108 135 129]
#   [110 147 137]
#   ...
#   [108 147 128]
#   [115 160 135]
#   [118 167 144]]]
# (300, 32, 32, 3)
# [[[0.6431373  0.78039217 0.5568628 ]
#   [0.6784314  0.7921569  0.61960787]
#   [0.7058824  0.8235294  0.65882355]
#   ...
#   [0.7529412  0.8784314  0.6509804 ]
#   [0.8117647  0.90588236 0.6784314 ]
#   [0.8156863  0.8901961  0.6431373 ]]
#
#  [[0.53333336 0.68235296 0.49411765]
#   [0.5882353  0.7176471  0.57254905]
#   [0.6313726  0.7529412  0.6       ]
#   ...
#   [0.83137256 0.90588236 0.6627451 ]
#   [0.76862746 0.87058824 0.6156863 ]
#   [0.8156863  0.9019608  0.6509804 ]]
#
#  [[0.53333336 0.67058825 0.50980395]
#   [0.57254905 0.69803923 0.5568628 ]
#   [0.6117647  0.70980394 0.54509807]
#   ...
#   [0.83137256 0.8901961  0.6862745 ]
#   [0.76862746 0.84313726 0.6392157 ]
#   [0.7372549  0.81960785 0.63529414]]
#
#  ...
#
#  [[0.30588236 0.43529412 0.42745098]
#   [0.27450982 0.39215687 0.36862746]
#   [0.36078432 0.49019608 0.45882353]
#   ...
#   [0.4117647  0.43529412 0.39215687]
#   [0.3137255  0.33333334 0.2901961 ]
#   [0.4745098  0.48235294 0.41960785]]
#
#  [[0.42352942 0.4745098  0.4745098 ]
#   [0.40784314 0.4392157  0.46666667]
#   [0.39607844 0.4745098  0.45882353]
#   ...
#   [0.5058824  0.57254905 0.50980395]
#   [0.40784314 0.5411765  0.45882353]
#   [0.4862745  0.5764706  0.5058824 ]]
#
#  [[0.46666667 0.5372549  0.5019608 ]
#   [0.42352942 0.5294118  0.5058824 ]
#   [0.43137255 0.5764706  0.5372549 ]
#   ...
#   [0.42352942 0.5764706  0.5019608 ]
#   [0.4509804  0.627451   0.5294118 ]
#   [0.4627451  0.654902   0.5647059 ]]]

# %% [markdown]
# ###  훈련, 검증, 테스트 데이타 구분

# %%
 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=0)

 
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2,
                                                  random_state=0)
 
print((X_train.shape, y_train.shape))
print((X_val.shape, y_val.shape))
print((X_test.shape, y_test.shape))
# Out:
# ((192, 32, 32, 3), (192, 3))
# ((48, 32, 32, 3), (48, 3))
# ((60, 32, 32, 3), (60, 3))

# %% [markdown]
# ## 2. 전이학습을 위하여 VGG16 사용

# %%
# cnn_model.py 파일 코드
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG16
from tensorflow.keras import Input, models, layers, optimizers, metrics

# CNN 모델 정의하기
def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', 
                     input_shape=in_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    return model

def trans_model(in_shape, nb_classes):
    transfer_model = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
    transfer_model.trainable = False
    transfer_model.summary()
    
    # 우리의 모델을 설정합니다.
    finetune_model = models.Sequential()
    finetune_model.add(transfer_model)
    finetune_model.add(Flatten())
    finetune_model.add(Dense(512, activation='relu'))
    finetune_model.add(Dropout(0.5))
    finetune_model.add(Dense(nb_classes, activation='softmax'))
    return finetune_model


def get_model(in_shape, nb_classes):
    model = trans_model(in_shape, nb_classes)
    model.compile(
        loss='categorical_crossentropy',
        optimizer = Adam(1e-4),
        metrics=['acc'])
    return model

# %% [markdown]
# ## CNN 모델 학습

# %% [markdown]
# ###  ModelCheckpoint, Early_stopping  지정

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os


MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model/CNN_animal1.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ### 2) 모델 학습

# %%
# import cnn_model   

# im_rows = 32  
# im_cols = 32  
# im_color = 3  
# in_shape = (im_rows, im_cols, im_color) 
# nb_classes = 3  

# model = get_model(in_shape, nb_classes)
# model.summary()

# 896=3*3*3*32+32
# 9248=3*3*32*32+32
# 18496=3*3*32*64+64
# 36928=3*3*64*64+64
# 819712=1600*512+512
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 512)               4194816
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 18911043 (72.14 MB)
# Trainable params: 4196355 (16.01 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# import cnn_model   

im_rows = 32  
im_cols = 32  
im_color = 3  
in_shape = (im_rows, im_cols, im_color) 
nb_classes = 3  

model = get_model(in_shape, nb_classes)

history = model.fit(X_train, y_train,
          batch_size=32,
          epochs=120,
          verbose=1,
          validation_data=(X_val, y_val),
          callbacks=[checkpointer])
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/120
# 5/6 [========================>.....] - ETA: 0s - loss: 1.3171 - acc: 0.3875
# Epoch 1: val_loss did not improve from 0.74013
# 6/6 [==============================] - 1s 91ms/step - loss: 1.2598 - acc: 0.4167 - val_loss: 1.1547 - val_acc: 0.3542
# Epoch 2/120
# 5/6 [========================>.....] - ETA: 0s - loss: 1.2109 - acc: 0.3625
# Epoch 2: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 58ms/step - loss: 1.2055 - acc: 0.3698 - val_loss: 1.0284 - val_acc: 0.3958
# Epoch 3/120
# 5/6 [========================>.....] - ETA: 0s - loss: 1.1143 - acc: 0.4187
# Epoch 3: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 59ms/step - loss: 1.1107 - acc: 0.4323 - val_loss: 0.9778 - val_acc: 0.5208
# Epoch 4/120
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0874 - acc: 0.4563
# Epoch 4: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 59ms/step - loss: 1.1144 - acc: 0.4271 - val_loss: 0.9391 - val_acc: 0.6042
# Epoch 5/120
# 5/6 [========================>.....] - ETA: 0s - loss: 1.0328 - acc: 0.4625
# Epoch 5: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 56ms/step - loss: 1.0224 - acc: 0.4896 - val_loss: 0.9114 - val_acc: 0.6250
# Epoch 6/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.9522 - acc: 0.5375
# Epoch 6: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 56ms/step - loss: 0.9608 - acc: 0.5312 - val_loss: 0.8911 - val_acc: 0.6250
# Epoch 7/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.9762 - acc: 0.5312
# Epoch 7: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 58ms/step - loss: 0.9883 - acc: 0.5208 - val_loss: 0.8748 - val_acc: 0.6250
# Epoch 8/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.9917 - acc: 0.5312
# Epoch 8: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 57ms/step - loss: 0.9755 - acc: 0.5417 - val_loss: 0.8645 - val_acc: 0.6458
# Epoch 9/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.9075 - acc: 0.5875
# Epoch 9: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 57ms/step - loss: 0.9135 - acc: 0.5677 - val_loss: 0.8502 - val_acc: 0.6667
# Epoch 10/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.9176 - acc: 0.5625
# Epoch 10: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 59ms/step - loss: 0.8999 - acc: 0.5781 - val_loss: 0.8397 - val_acc: 0.7083
# Epoch 11/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.9037 - acc: 0.5813
# Epoch 11: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 58ms/step - loss: 0.9007 - acc: 0.5833 - val_loss: 0.8261 - val_acc: 0.7083
# Epoch 12/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.8792 - acc: 0.5750
# Epoch 12: val_loss did not improve from 0.74013
# 6/6 [==============================] - 0s 57ms/step - loss: 0
val_loss did not improve from 0.73593
# 6/6 [==============================] - 0s 58ms/step - loss: 0.3364 - acc: 0.9062 - val_loss: 0.7651 - val_acc: 0.6875
# Epoch 117/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3107 - acc: 0.9250
# Epoch 117: val_loss did not improve from 0.73593
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3117 - acc: 0.9271 - val_loss: 0.7648 - val_acc: 0.6875
# Epoch 118/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3478 - acc: 0.9000
# Epoch 118: val_loss did not improve from 0.73593
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3469 - acc: 0.8958 - val_loss: 0.7646 - val_acc: 0.6875
# Epoch 119/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3405 - acc: 0.9312
# Epoch 119: val_loss did not improve from 0.73593
# 6/6 [==============================] - 0s 55ms/step - loss: 0.3166 - acc: 0.9427 - val_loss: 0.7669 - val_acc: 0.6875
# Epoch 120/120
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3218 - acc: 0.9125
# Epoch 120: val_loss did not improve from 0.73593
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2945 - acc: 0.9271 - val_loss: 0.7693 - val_acc: 0.6667

# %% [markdown]
# ## 5. 모델 평가

# %%
score = model.evaluate(X_test, y_test)
print(score)
print(('정답률 =', score[1], 'loss =', score[0]))
# Out:
# 2/2 [==============================] - 0s 39ms/step - loss: 0.8149 - acc: 0.6500
# [0.8149242401123047, 0.6499999761581421]
# ('정답률 =', 0.6499999761581421, 'loss =', 0.8149242401123047)

# %%
list(history.history.keys())
# Out:
# ['loss', 'acc', 'val_loss', 'val_acc']

# %% [markdown]
# loss : 훈련 손실값
# acc : 훈련 정확도
# val_loss : 검증 손실값
# val_acc : 검증 정확도

# %%
pprint(history.history)
# Out:
# {'acc': [0.2760416567325592,
#          0.3229166567325592,
#          0.34375,
#          0.3645833432674408,
#          0.3489583432674408,
#          0.46875,
#          0.4479166567325592,
#          0.5208333134651184,
#          0.4895833432674408,
#          0.578125,
#          0.5104166865348816,
#          0.5677083134651184,
#          0.5729166865348816,
#          0.5677083134651184,
#          0.6145833134651184,
#          0.6302083134651184,
#          0.5833333134651184,
#          0.59375,
#          0.5833333134651184,
#          0.6145833134651184,
#          0.578125,
#          0.6302083134651184,
#          0.6458333134651184,
#          0.6458333134651184,
#          0.671875,
#          0.6302083134651184,
#          0.6666666865348816,
#          0.6875,
#          0.6458333134651184,
#          0.6822916865348816],
#  'loss': [1.4048839807510376,
#           1.2609223127365112,
#           1.1829849481582642,
#           1.0970697402954102,
#           1.1034852266311646,
#           1.0216360092163086,
#           1.043160080909729,
#           1.0135964155197144,
#           0.9900436997413635,
#           0.8955593109130859,
#           0.9529524445533752,
#           0.9209900498390198,
#           0.901731014251709,
#           0.9155504703521729,
#           0.8682604432106018,
#           0.870833158493042,
#           0.8626428246498108,
#           0.8313094973564148,
#           0.8736104369163513,
#           0.8338369727134705,
#           0.8292161822319031,
#           0.8250506520271301,
#           0.7978112101554871,
#           0.8345310091972351,
#           0.7614046931266785,
#           0.8019924163818359,
#           0.7700324058532715,
#           0.7220438122749329,
#           0.7829390168190002,
#           0.7240089774131775],
#  'val_acc': [0.4166666567325592,
#              0.3541666567325592,
#              0.4375,
#              0.4583333432674408,
#              0.4375,
#              0.4791666567325592,
#              0.5416666865348816,
#              0.6041666865348816,
#              0.6458333134651184,
#              0.6666666865348816,
#              0.6666666865348816,
#              0.6666666865348816,
#              0.6666666865348816,
#              0.6666666865348816,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.7083333134651184,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.6875,
#              0.7083333134651184,
#              0.6875],
#  'val_loss': [1.1020630598068237,
#               1.0593782663345337,
#               1.050470232963562,
#               1.0352472066879272,
#               1.0031412839889526,
#               0.9712652564048767,
#               0.9369946122169495,
#               0.905738353729248,
#               0.8808895945549011,
#               0.8667570948600769,
#               0.8499857783317566,
#               0.833841860294342,
#               0.8246950507164001,
#               0.8159402012825012,
#               0.8058968186378479,
#               0.8011453747749329,
#               0.7944474220275879,
#               0.7855774760246277,
#               0.7758631110191345,
#               0.769697368144989,
#               0.7663479447364807,
#               0.7661061882972717,
#               0.7643144726753235,
#               0.7640429139137268,
#               0.7606620788574219,
#               0.752448558807373,
#               0.7475047707557678,
#               0.7453498840332031,
#               0.7431239485740662,
#               0.7401253581047058]}

# %%
import matplotlib.pyplot as plt
his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] 
epochs = list(range(1, len(loss) + 1))
fig = plt.figure(figsize = (10, 5))

# 훈련 및 검증 손실 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc']
val_acc = his_dict['val_acc']

# 훈련 및 검증 정확도 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2

photos = np.load('image/photos.npz')
x = photos['x']
img = x[150] 

plt.figure(figsize=(10,10))
for i in range(36):
    plt.subplot(6,6,i+1)
    center = (16, 16) 
    angle = i * 5 
    scale = 1.0  
    mtx = cv2.getRotationMatrix2D(center, angle, scale)
    img2 = cv2.warpAffine(img, mtx, (32, 32))
    plt.imshow(img2)
plt.show()

# %%
# import cnn_model
import tensorflow.keras
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import cv2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os

im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

photos = np.load('image/photos.npz')
X = photos['x']
y = photos['y']

# X 속성 데이터를 3차원 배열로 변환, 정규화하기
X = x.reshape(-1, im_rows, im_cols, im_color)
X = x.astype('float32') / 255

y = to_categorical(y.astype('int32'), nb_classes)

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2,
                                                   random_state=0)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2,
                                                  random_state=0)

x_new = []
y_new = []
for i, xi in enumerate(X_train):
    yi = y_train[i]
    for ang in range(-30, 30, 5):
        # 회전 시키기 
        center = (16, 16) # 회전 중심
        mtx = cv2.getRotationMatrix2D(center, ang, 1.0)
        xi2 = cv2.warpAffine(xi, mtx, (32, 32))
        x_new.append(xi2)
        y_new.append(yi)
        # 좌우 반전 
        xi3 = cv2.flip(xi2, 1)
        x_new.append(xi3)
        y_new.append(yi)

print(('수량을 늘리기 전=', len(y_train)))
X_train = np.array(x_new)
y_train = np.array(y_new)
print(('수량을 늘린 후=', len(y_train)))
print(('-'*70))
# Out:
# ('수량을 늘리기 전=', 192)
# ('수량을 늘린 후=', 4608)
# ----------------------------------------------------------------------

# %%
model = get_model(in_shape, nb_classes)


MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model/CNN_animal2.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 14978883 (57.14 MB)
# Trainable params: 264195 (1.01 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# 모델 학습 
history = model.fit(X_train, y_train,
          batch_size=32,
          epochs=30,
          verbose=1,
          validation_data=(X_val, y_val),
          callbacks=[checkpointer])
# Out:
# Epoch 1/30
# 144/144 [==============================] - ETA: 0s - loss: 1.0101 - acc: 0.4876
# Epoch 1: val_loss improved from inf to 0.80488, saving model to ./model\CNN_animal2.hdf5
# 144/144 [==============================] - 8s 52ms/step - loss: 1.0101 - acc: 0.4876 - val_loss: 0.8049 - val_acc: 0.6042
# Epoch 2/30
# 144/144 [==============================] - ETA: 0s - loss: 0.7964 - acc: 0.6345
# Epoch 2: val_loss improved from 0.80488 to 0.78960, saving model to ./model\CNN_animal2.hdf5
# 144/144 [==============================] - 7s 46ms/step - loss: 0.7964 - acc: 0.6345 - val_loss: 0.7896 - val_acc: 0.6875
# Epoch 3/30
# 144/144 [==============================] - ETA: 0s - loss: 0.7018 - acc: 0.6927
# Epoch 3: val_loss improved from 0.78960 to 0.78236, saving model to ./model\CNN_animal2.hdf5
# 144/144 [==============================] - 6s 45ms/step - loss: 0.7018 - acc: 0.6927 - val_loss: 0.7824 - val_acc: 0.6458
# Epoch 4/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.6267 - acc: 0.7397
# Epoch 4: val_loss improved from 0.78236 to 0.77544, saving model to ./model\CNN_animal2.hdf5
# 144/144 [==============================] - 6s 44ms/step - loss: 0.6272 - acc: 0.7396 - val_loss: 0.7754 - val_acc: 0.7083
# Epoch 5/30
# 144/144 [==============================] - ETA: 0s - loss: 0.5690 - acc: 0.7700
# Epoch 5: val_loss did not improve from 0.77544
# 144/144 [==============================] - 6s 45ms/step - loss: 0.5690 - acc: 0.7700 - val_loss: 0.8021 - val_acc: 0.6042
# Epoch 6/30
# 144/144 [==============================] - ETA: 0s - loss: 0.5088 - acc: 0.8030
# Epoch 6: val_loss did not improve from 0.77544
# 144/144 [==============================] - 6s 45ms/step - loss: 0.5088 - acc: 0.8030 - val_loss: 0.7814 - val_acc: 0.6667
# Epoch 7/30
# 144/144 [==============================] - ETA: 0s - loss: 0.4646 - acc: 0.8314
# Epoch 7: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.4646 - acc: 0.8314 - val_loss: 0.8015 - val_acc: 0.6042
# Epoch 8/30
# 144/144 [==============================] - ETA: 0s - loss: 0.4275 - acc: 0.8472
# Epoch 8: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 45ms/step - loss: 0.4275 - acc: 0.8472 - val_loss: 0.7960 - val_acc: 0.6250
# Epoch 9/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.3881 - acc: 0.8770
# Epoch 9: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.3887 - acc: 0.8765 - val_loss: 0.8052 - val_acc: 0.6458
# Epoch 10/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.3560 - acc: 0.8947
# Epoch 10: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.3565 - acc: 0.8941 - val_loss: 0.8117 - val_acc: 0.6458
# Epoch 11/30
# 144/144 [==============================] - ETA: 0s - loss: 0.3244 - acc: 0.9054
# Epoch 11: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 47ms/step - loss: 0.3244 - acc: 0.9054 - val_loss: 0.8319 - val_acc: 0.6875
# Epoch 12/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.2974 - acc: 0.9205
# Epoch 12: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 48ms/step - loss: 0.2970 - acc: 0.9208 - val_loss: 0.8559 - val_acc: 0.6875
# Epoch 13/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.2699 - acc: 0.9253
# Epoch 13: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 48ms/step - loss: 0.2698 - acc: 0.9256 - val_loss: 0.8448 - val_acc: 0.7083
# Epoch 14/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.2503 - acc: 0.9375
# Epoch 14: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 47ms/step - loss: 0.2498 - acc: 0.9379 - val_loss: 0.8569 - val_acc: 0.7083
# Epoch 15/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.2296 - acc: 0.9454
# Epoch 15: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 47ms/step - loss: 0.2299 - acc: 0.9449 - val_loss: 0.8744 - val_acc: 0.6875
# Epoch 16/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.2115 - acc: 0.9524
# Epoch 16: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 47ms/step - loss: 0.2113 - acc: 0.9527 - val_loss: 0.8728 - val_acc: 0.6875
# Epoch 17/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.1926 - acc: 0.9574
# Epoch 17: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.1926 - acc: 0.9575 - val_loss: 0.8710 - val_acc: 0.7083
# Epoch 18/30
# 144/144 [==============================] - ETA: 0s - loss: 0.1772 - acc: 0.9657
# Epoch 18: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 45ms/step - loss: 0.1772 - acc: 0.9657 - val_loss: 0.8985 - val_acc: 0.7083
# Epoch 19/30
# 144/144 [==============================] - ETA: 0s - loss: 0.1688 - acc: 0.9696
# Epoch 19: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 45ms/step - loss: 0.1688 - acc: 0.9696 - val_loss: 0.9159 - val_acc: 0.7292
# Epoch 20/30
# 144/144 [==============================] - ETA: 0s - loss: 0.1519 - acc: 0.9711
# Epoch 20: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 45ms/step - loss: 0.1519 - acc: 0.9711 - val_loss: 0.9105 - val_acc: 0.7083
# Epoch 21/30
# 144/144 [==============================] - ETA: 0s - loss: 0.1441 - acc: 0.9718
# Epoch 21: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.1441 - acc: 0.9718 - val_loss: 0.9101 - val_acc: 0.7083
# Epoch 22/30
# 144/144 [==============================] - ETA: 0s - loss: 0.1311 - acc: 0.9798
# Epoch 22: val_loss did not improve from 0.77544
# 144/144 [==============================] - 6s 45ms/step - loss: 0.1311 - acc: 0.9798 - val_loss: 0.9413 - val_acc: 0.7083
# Epoch 23/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.1221 - acc: 0.9795
# Epoch 23: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 45ms/step - loss: 0.1220 - acc: 0.9794 - val_loss: 0.9419 - val_acc: 0.7083
# Epoch 24/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.1130 - acc: 0.9821
# Epoch 24: val_loss did not improve from 0.77544
# 144/144 [==============================] - 6s 45ms/step - loss: 0.1129 - acc: 0.9822 - val_loss: 0.9566 - val_acc: 0.7292
# Epoch 25/30
# 144/144 [==============================] - ETA: 0s - loss: 0.1064 - acc: 0.9826
# Epoch 25: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 45ms/step - loss: 0.1064 - acc: 0.9826 - val_loss: 0.9621 - val_acc: 0.7292
# Epoch 26/30
# 144/144 [==============================] - ETA: 0s - loss: 0.0995 - acc: 0.9859
# Epoch 26: val_loss did not improve from 0.77544
# 144/144 [==============================] - 6s 45ms/step - loss: 0.0995 - acc: 0.9859 - val_loss: 0.9678 - val_acc: 0.7083
# Epoch 27/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.0913 - acc: 0.9867
# Epoch 27: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.0910 - acc: 0.9868 - val_loss: 0.9716 - val_acc: 0.7083
# Epoch 28/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.0878 - acc: 0.9865
# Epoch 28: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.0877 - acc: 0.9865 - val_loss: 0.9849 - val_acc: 0.7500
# Epoch 29/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.0804 - acc: 0.9899
# Epoch 29: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.0801 - acc: 0.9900 - val_loss: 0.9839 - val_acc: 0.7500
# Epoch 30/30
# 143/144 [============================>.] - ETA: 0s - loss: 0.0742 - acc: 0.9902
# Epoch 30: val_loss did not improve from 0.77544
# 144/144 [==============================] - 7s 46ms/step - loss: 0.0745 - acc: 0.9898 - val_loss: 1.0120 - val_acc: 0.7292

# %%
# 학습 과정 시각화 
import matplotlib.pyplot as plt
his_dict = history.history
loss = his_dict['loss']
val_loss = his_dict['val_loss'] 
epochs = list(range(1, len(loss) + 1))
fig = plt.figure(figsize = (10, 5))

# 학습 및 데트스 손실(loss) 그리기
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, color = 'blue', label = 'train_loss')
ax1.plot(epochs, val_loss, color = 'orange', label = 'val_loss')
ax1.set_title('train and val loss')
ax1.set_xlabel('epochs')
ax1.set_ylabel('loss')
ax1.legend()

acc = his_dict['acc']
val_acc = his_dict['val_acc']

# 학습 및 데이타 정확도(accuracy) 그리기
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, acc, color = 'blue', label = 'train_acc')
ax2.plot(epochs, val_acc, color = 'orange', label = 'val_acc')
ax2.set_title('train and val acc')
ax2.set_xlabel('epochs')
ax2.set_ylabel('acc')
ax2.legend()
plt.show()
